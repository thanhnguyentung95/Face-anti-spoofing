# %%
from imutils import paths
import os
from os.path import join

# %%
imagePaths = list(paths.list_images('CASIA-SURF'))

# %%
total = 0
removed = 0
for imagePath in imagePaths:
    total += 1
    if 'depth' in imagePath or 'ir' in imagePath:
        os.remove(imagePath)
        removed += 1

print('total ', total)
print('removed ', removed)
# Out:
# total  26608
# removed  17666

# %%
subcasias = os.listdir('CASIA-SURF')

# %%
for subcasia in subcasias:
    subcat = os.listdir(join('CASIA-SURF',subcasia))
    print(subcat)
# Out:
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ['real.rssdk']
# ...

# %%
from glob import glob
glob(os.path.join('CASIA-SURF', "*", ""), recursive=True)
# Out:
# ['CASIA-SURF/CLKJ_BS0858/',
#  'CASIA-SURF/CLKJ_AS0011/',
#  'CASIA-SURF/CLKJ_BS0772/',
#  'CASIA-SURF/CLKJ_AS0176/',
#  'CASIA-SURF/CLKJ_BS1327/',
#  'CASIA-SURF/CLKJ_BS0768/',
#  'CASIA-SURF/CLKJ_BS0741/',
#  'CASIA-SURF/CLKJ_CS0056/',
#  'CASIA-SURF/CLKJ_AS0137/',
#  'CASIA-SURF/CLKJ_BS0225/',
#  'CASIA-SURF/CLKJ_CS0029/',
#  'CASIA-SURF/CLKJ_AS0178/',
#  'CASIA-SURF/CLKJ_BS0051/',
#  'CASIA-SURF/CLKJ_BS0518/',
#  'CASIA-SURF/CLKJ_BS0252/',
#  'CASIA-SURF/CLKJ_BS0170/',
#  'CASIA-SURF/CLKJ_BS0285/',
#  'CASIA-SURF/CLKJ_BS1088/',
#  'CASIA-SURF/CLKJ_BS0841/',
#  'CASIA-SURF/CLKJ_BS1032/',
#  'CASIA-SURF/CLKJ_BS1144/',
#  'CASIA-SURF/CLKJ_BS1081/',
#  'CASIA-SURF/CLKJ_BS1000/',
#  'CASIA-SURF/CLKJ_AS0275/',
#  'CASIA-SURF/CLKJ_BS0290/',
#  'CASIA-SURF/CLKJ_BS1495/',
#  'CASIA-SURF/CLKJ_BS1256/',
#  'CASIA-SURF/CLKJ_BS0576/',
#  'CASIA-SURF/CLKJ_BS1179/',
#  'CASIA-SURF/CLKJ_BS1010/',
#  'CASIA-SURF/CLKJ_BS0750/',
#  'CASIA-SURF/CLKJ_BS0211/',
#  'CASIA-SURF/CLKJ_CS0004/',
# ...

# %%
from pathlib import Path

count_depth = 0
count_ir = 0
for path in Path('CASIA-SURF').rglob('*'):
    if 'depth' in str(path.stem) or 'or' in str(path.stem):
# Out:
# depth  297
# ir  297
